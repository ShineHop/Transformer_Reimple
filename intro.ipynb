# %%
import torch
import numpy as np

# %%
torch.cuda.is_available()
# Out:
# True

# %%
from datasets import load_dataset
dataset = load_dataset('iwslt2017', 'iwslt2017-en-de')

# %%
train_data = dataset['train']['translation']

# %%
valid_data = dataset['validation']['translation']

# %%
test_data = dataset['test']['translation']

# %%
import json
with open("/home/sihyeon/en_de_data.json", 'w') as f:
    json.dump(train_data, f) #ensure_ascii=False

# %%
with open("/home/sihyeon/en_de_data.json", 'r') as f:
    train_data = json.load(f)

# %%
len(train_data)

# %%
print(dataset)

# %%
dataset['validation']['translation']

# %% [markdown]
# Create test_corpus.txt

# %%
corpus=[]
for i in range(len(train_data)):
    corpus.append(train_data[i]['en'])
corpus
# Out:
# ['Thank you so much, Chris.',
#  "And it's truly a great honor to have the opportunity to come to this stage twice; I'm extremely grateful.",
#  'I have been blown away by this conference, and I want to thank all of you for the many nice comments about what I had to say the other night.',
#  'And I say that sincerely, partly because  I need that.',
#  'Put yourselves in my position.',
#  'I flew on Air Force Two for eight years.',
#  'Now I have to take off my shoes or boots to get on an airplane!',
#  "I'll tell you one quick story to illustrate what that's been like for me.",
#  "It's a true story -- every bit of this is true.",
#  'Soon after Tipper and I left the --  White House --  we were driving from our home in Nashville to a little farm we have 50 miles east of Nashville.',
#  'Driving ourselves.',
#  'I know it sounds like a little thing to you, but --  I looked in the rear-view mirror and all of a sudden it just hit me.',
#  'There was no motorcade back there.',
# ...

# %%
corpus[:5]

# %%
f = open("/home/sihyeon/en_corpus_train.txt", 'w')
for i in range(len(corpus)):
    data = corpus[i]+"\n"
    f.write(data)
f.close()

# %%
import torch
torch.__version__

# %%
# !nvcc --version
